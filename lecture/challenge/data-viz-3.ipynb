# %%
# imports

# %% [markdown]
# ## Visualizing date-time data with UFOs!

# %%
# Read in the dataset
# Out:
# Index(['Unnamed: 0', 'City', 'Colors Reported', 'Shape Reported', 'State',
#        'Time', 'Date', 'Year', 'Month', 'Day', 'Hour', 'Weekday',
#        'weekday_name', 'weekday_cats', 'sightings'],
#       dtype='object')

# %%
# Check out the time variable
# Out:
# count                   80543
# unique                  68901
# top       2014-07-04 22:00:00
# freq                       45
# Name: Time, dtype: object

# %%
# What type of var is it?
# Out:
# dtype('O')

# %%
# convert a string to the datetime format
# Out:
# dtype('<M8[ns]')

# %%
# create new variables! Start with 'date'
# Out:
#    Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time        Date  Year  Month  Day  Hour  Weekday  \
# 0 1930-06-01 22:00:00  1930-06-01  1930      6    1    22        6
# 1 1930-06-30 20:00:00  1930-06-30  1930      6   30    20        0
# 2 1931-02-15 14:00:00  1931-02-15  1931      2   15    14        6
# 3 1931-06-01 13:00:00  1931-06-01  1931      6    1    13        0
# 4 1933-04-18 19:00:00  1933-04-18  1933      4   18    19        1
#
#   weekday_name weekday_cats  sightings
# 0     Saturday     Saturday          1
# 1       Sunday       Sunday          1
# 2     Saturday     Saturday          1
# 3       Sunday       Sunday          1
# 4       Monday       Monday          1

# %%
# Create some additional variables
# Out:
#    Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time        Date  Year  Month  Day  Hour  Weekday  \
# 0 1930-06-01 22:00:00  1930-06-01  1930      6    1    22        6
# 1 1930-06-30 20:00:00  1930-06-30  1930      6   30    20        0
# 2 1931-02-15 14:00:00  1931-02-15  1931      2   15    14        6
# 3 1931-06-01 13:00:00  1931-06-01  1931      6    1    13        0
# 4 1933-04-18 19:00:00  1933-04-18  1933      4   18    19        1
#
#   weekday_name weekday_cats  sightings
# 0     Saturday     Saturday          1
# 1       Sunday       Sunday          1
# 2     Saturday     Saturday          1
# 3       Sunday       Sunday          1
# 4       Monday       Monday          1

# %%
# also allows you to do datetime "math"
# Out:
# 30776

# %% [markdown]
# ## Creating a categorical variable with proper sorting

# %%
# Create a weekday variable using map and numeration
# Out:
#    Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time        Date  Year  Month  Day  Hour  Weekday  \
# 0 1930-06-01 22:00:00  1930-06-01  1930      6    1    22        6
# 1 1930-06-30 20:00:00  1930-06-30  1930      6   30    20        0
# 2 1931-02-15 14:00:00  1931-02-15  1931      2   15    14        6
# 3 1931-06-01 13:00:00  1931-06-01  1931      6    1    13        0
# 4 1933-04-18 19:00:00  1933-04-18  1933      4   18    19        1
#
#   weekday_name weekday_cats  sightings
# 0     Saturday     Saturday          1
# 1       Sunday       Sunday          1
# 2     Saturday     Saturday          1
# 3       Sunday       Sunday          1
# 4       Monday       Monday          1

# %%
# but the problem with this is that it doesn't display in the right order.
# Out:
#               weekday_name
# weekday_name
# Wednesday            11032
# Tuesday              10976
# Thursday             11759
# Sunday               10039
# Saturday             11709
# Monday               10783
# Friday               14245

# %%
# and it also screws up the ordering in your visualizations.

# %%
# the solution is to create a new var with dtype 'category'
# Out:
#        Weekday weekday_name weekday_cats
# 60962        6     Saturday     Saturday
# 67510        2      Tuesday      Tuesday
# 60213        2      Tuesday      Tuesday

# %%
a

# %%
# now the days will appear in the proper order!
# Out:
#               weekday_cats
# weekday_cats
# Sunday               10039
# Saturday             11709
# Friday               14245
# Thursday             11759
# Wednesday            11032
# Tuesday              10976
# Monday               10783

# %%
# and this sort order will also transfer to your visualizations

# %% [markdown]
# ## Plotting line charts with time series data

# %%
# which dates were the most frequent ufo sightings?
# Out:
# 2014-07-04    258
# 2010-07-04    202
# 2012-07-04    188
# 1999-11-16    187
# 2013-07-04    177
# Name: Date, dtype: int64

# %%
# # Set the Time variable as the dataframe index (This will make plotting timelines easier)
# ufo['Time2']=ufo['Time']
# ufo=ufo.set_index('Time2')

# %%
# Create a variable to count the number of sightings by date
# ufo['sightings']=1
# dates = ufo.groupby('Date')['sightings'].sum()
# ufo = ufo.drop('sightings', axis=1)
# dates.sort_values(ascending=False).head()

# %%
# Create a new dataframe of sightings
# dates_df = pd.DataFrame(dates)
# dates_df= dates_df.reset_index()
# dates_df.sort_values('sightings', ascending=False).head()

# %%
# Merge the daily number of sightings back into the original datafram
# ufo2 = pd.merge(ufo, dates_df, on='Date', how='left')
# ufo2.to_csv('../data/ufo2.csv')

# %%
# what's the average number of sightings on a given day?
# Out:
# 18.735296673826404

# %%
# Trend over years

# %%
# Trend over weekday

# %%
# Trend over time of day

# %%
# Trend over month

# %% [markdown]
# ## Plot multiple lines in color

# %%
# First, let's shorten the number of color categories. There are too many!
# Out:
# ORANGE            5216
# RED               4809
# GREEN             1897
# BLUE              1855
# YELLOW             842
# RED ORANGE         486
# RED GREEN          469
# RED BLUE           445
# RED GREEN BLUE     166
# GREEN BLUE         147
# RED YELLOW         146
# ORANGE YELLOW      137
# ORANGE GREEN        66
# ORANGE BLUE         58
# YELLOW GREEN        53
# Name: Colors Reported, dtype: int64

# %%
# we can create a new variable with only 4 categories.
# Out:
# other     68621
# orange     5216
# red        4809
# green      1897
# Name: color, dtype: int64

# %%
# Alternative: we can create new columns for specific colors using numpy. This is called "one-hot encoding".
# Out:
#    Unnamed: 0                  City Colors Reported Shape Reported State  \
# 0           0                Ithaca             NaN       TRIANGLE    NY
# 1           1           Willingboro             NaN          OTHER    NJ
# 2           2               Holyoke             NaN           OVAL    CO
# 3           3               Abilene             NaN           DISK    KS
# 4           4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time        Date  Year  Month  Day  ...  Weekday  \
# 0 1930-06-01 22:00:00  1930-06-01  1930      6    1  ...        6
# 1 1930-06-30 20:00:00  1930-06-30  1930      6   30  ...        0
# 2 1931-02-15 14:00:00  1931-02-15  1931      2   15  ...        6
# 3 1931-06-01 13:00:00  1931-06-01  1931      6    1  ...        0
# 4 1933-04-18 19:00:00  1933-04-18  1933      4   18  ...        1
#
#    weekday_name weekday_cats sightings  color orange  red  green  other_color  \
# 0      Saturday     Saturday         1  other      0    0      0            1
# 1        Sunday       Sunday         1  other      0    0      0            1
# 2      Saturday     Saturday         1  other      0    0      0            1
# 3        Sunday       Sunday         1  other      0    0      0            1
# 4        Monday       Monday         1  other      0    0      0            1
#
#    sighting
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#
# [5 rows x 21 columns]

# %%
# Create a new dataset by collapsing the original dataframe on color and date
# Out:
#      Year   color  sighting
# 245  2009   green        82
# 246  2009  orange       220
# 247  2009   other      3689
# 248  2009     red       260

# %%
# Plot the lines

# %%
# Restrict the dataset to only the last 20 years (this makes the chart a lot easier to read)

# %%
# Now plot the lines for this shorter time period

# %%
# Plot the lines in color!!

# %%
# you can also do this with a for-loop, using 3 filters, one for each color and use hex codes.

# %%
# an alternative is to use "style" instead of "hue".
